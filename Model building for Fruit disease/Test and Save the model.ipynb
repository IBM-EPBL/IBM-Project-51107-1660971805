# %%
model.save('fruitdata.h5')

# %%
model.save('fruitdata.h5')

# %%
img=image.load_img(r"D:/Rishika/Documents/GitHub/IBM-Project-31930-1660206641/Dataset Plant Disease/fruit-dataset/fruit-dataset/test/Apple___healthy/01b32971-5125-4982-98e2-22daa9ae864a___RS_HL 7977.JPG")
img

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
x=image.img_to_array(img)
img=image.load_img(r"D:/Rishika/Documents/GitHub/IBM-Project-31930-1660206641/Dataset Plant Disease/fruit-dataset/fruit-dataset/test/Apple___healthy/01b32971-5125-4982-98e2-22daa9ae864a___RS_HL 7977.JPG",target_size=(128,128))
img

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
x=image.img_to_array(img)
x

# %% [markdown]
# array([[[168., 155., 172.],
#         [166., 153., 170.],
#         [167., 154., 171.],
#         ...,
#         [ 68.,  61.,  79.],
#         [ 71.,  64.,  82.],
#         [ 68.,  61.,  79.]],
#
#        [[178., 165., 182.],
#         [173., 160., 177.],
#         [171., 158., 175.],
#         ...,
#         [ 73.,  66.,  84.],
#         [ 78.,  71.,  89.],
#         [ 67.,  60.,  78.]],
#
#        [[176., 163., 180.],
#         [172., 159., 176.],
#         [171., 158., 175.],
#         ...,
#         [ 64.,  57.,  75.],
#         [ 74.,  67.,  85.],
#         [ 76.,  69.,  87.]],
#
#        ...,
#
#        [[130., 125., 148.],
#         [130., 125., 148.],
#         [139., 134., 157.],
#         ...,
#         [ 55.,  55.,  79.],
#         [ 54.,  54.,  78.],
#         [ 59.,  59.,  83.]],
#
#        [[137., 132., 155.],
#         [128., 123., 146.],
#         [136., 131., 154.],
#         ...,
#         [ 63.,  63.,  87.],
#         [ 59.,  59.,  83.],
#         [ 65.,  65.,  89.]],
#
#        [[138., 133., 156.],
#         [135., 130., 153.],
#         [131., 126., 149.],
#         ...,
#         [ 62.,  62.,  86.],
#         [ 55.,  55.,  79.],
#         [ 60.,  60.,  84.]]], dtype=float32)

# %%
x=np.expand_dims(x,axis=0)
x

# %% [markdown]
# array([[[[168., 155., 172.],
#          [166., 153., 170.],
#          [167., 154., 171.],
#          ...,
#          [ 68.,  61.,  79.],
#          [ 71.,  64.,  82.],
#          [ 68.,  61.,  79.]],
#
#         [[178., 165., 182.],
#          [173., 160., 177.],
#          [171., 158., 175.],
#          ...,
#          [ 73.,  66.,  84.],
#          [ 78.,  71.,  89.],
#          [ 67.,  60.,  78.]],
#
#         [[176., 163., 180.],
#          [172., 159., 176.],
#          [171., 158., 175.],
#          ...,
#          [ 64.,  57.,  75.],
#          [ 74.,  67.,  85.],
#          [ 76.,  69.,  87.]],
#
#         ...,
#
#         [[130., 125., 148.],
#          [130., 125., 148.],
#          [139., 134., 157.],
#          ...,
#          [ 55.,  55.,  79.],
#          [ 54.,  54.,  78.],
#          [ 59.,  59.,  83.]],
#
#         [[137., 132., 155.],
#          [128., 123., 146.],
#          [136., 131., 154.],
#          ...,
#          [ 63.,  63.,  87.],
#          [ 59.,  59.,  83.],
#          [ 65.,  65.,  89.]],
#
#         [[138., 133., 156.],
#          [135., 130., 153.],
#          [131., 126., 149.],
#          ...,
#          [ 62.,  62.,  86.],
#          [ 55.,  55.,  79.],
#          [ 60.,  60.,  84.]]]], dtype=float32)

# %%
y=np.argmax(model.predict(x),axis=1)

# %% [markdown]
# 1/1 [==============================] - 0s 203ms/step

# %%
x_train.class_indices

# %% [markdown]
# {'Apple___Black_rot': 0,
#
# 'Apple___healthy': 1,
#
#  'Corn_(maize)___Northern_Leaf_Blight': 2,
#
#  'Corn_(maize)___healthy': 3,
#
#  'Peach___Bacterial_spot': 4,
#
#  'Peach___healthy': 5}

# %%
index=['Apple___Black_rot','Apple___healthy','Corn_(maize)___Northern_Leaf_Blight','Corn_(maize)___healthy','Peach___Bacterial_spot','Peach___healthy']
index[y[0]]

# %% [markdown]
# 'Peach___healthy'

# %%
img=image.load_img(r"D:/Rishika/Documents/GitHub/IBM-Project-31930-1660206641/Dataset Plant Disease/fruit-dataset/fruit-dataset/test/Apple___healthy/01b32971-5125-4982-98e2-22daa9ae864a___RS_HL 7977.JPG",target_size=(128,128))
x=image.img_to_array(img)
x=np.expand_dims(x,axis=0)
y=np.argmax(model.predict(x),axis=1)
index=['Apple___Black_rot','Apple___healthy','Corn_(maize)___Northern_Leaf_Blight','Corn_(maize)___healthy','Peach___Bacterial_spot','Peach___healthy']
index[y[0]]

# %% [markdown]
# 1/1 [==============================] - 0s 66ms/step
# 'Peach___healthy'
